# %% [markdown]
# <a href="https://colab.research.google.com/github/AlbertP97/Student-performance/blob/main/Student_Performance_(Por).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Importing Libraries

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Reading the Dataset

# %%
# Reading the dataset
por_dataset =pd.read_csv('/content/drive/MyDrive/Portafolio DS/Datasets/student-por.csv', delimiter=';')
por_dataset.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# # 3. Basic Data Exploration

# %%
# Basic data exploration
print(por_dataset.shape)
# Out:
# (649, 33)

# %%
por_dataset.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# Additional data exploration and information
por_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
por_dataset.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %% [markdown]
# # 4. Visualizing Categorical Data

# %%
# Visualizing categorical data
plt.figure(figsize=(12, 8))
por_dataset['school'].value_counts().plot(kind='pie')
plt.title('School: GP - Gabriel Pereira or MS - Mousinho da Silveira')
plt.show()

# %%
plt.figure(figsize=(12, 8))
por_dataset['sex'].value_counts().plot(kind="pie")
plt.title('Sex')
plt.show()

# %%
plt.figure(figsize=(12, 8))
por_dataset['age'].value_counts().plot(kind="bar")
plt.title('Age of students')
plt.show()

# %% [markdown]
# # 5. Visualizing Relationships and Distributions

# %%
# Visualizing relationships and distributions using Seaborn
plt.figure(figsize=(12, 8))
sns.countplot(data=por_dataset, x="age", hue="sex")
plt.title('Age & sex of students')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='age',y='G3', data=por_dataset)
plt.title('Age & G3 (Last grade)')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=por_dataset, x="famsize", hue="sex")
plt.title('Family size: LE3 - less or equal to 3 or GT3 - greater than 3 & Sex')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x="Pstatus", y="G3", data=por_dataset)
plt.title("Parent's status: T - living together or A - apart & G3 (Last grade)")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x="guardian", y="G3", data=por_dataset)
plt.title('Guardian & G3 (Last grade)')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=por_dataset, x="Medu", hue="sex")
plt.title('Mother education level by student sex:  0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=por_dataset, x="Mjob", hue="sex")
plt.title('Mother job type by student sex')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=por_dataset, x="Fjob", hue="sex")
plt.title('Father job type by student sex')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=por_dataset, x="reason", hue="sex")
plt.title('Reason to choose this school by student sex')
plt.show()

# %%
plt.figure(figsize=(12, 8))
por_dataset["schoolsup"].value_counts().plot(kind="pie")
plt.title('Extra educational support')
plt.show()

# %%
plt.figure(figsize=(12, 8))
por_dataset["famsup"].value_counts().plot(kind="pie")
plt.title('Family educational support')
plt.show()

# %%
plt.figure(figsize=(12, 8))
por_dataset["paid"].value_counts().plot(kind="pie")
plt.title('Extra paid classes')
plt.show()

# %%
plt.figure(figsize=(12, 8))
por_dataset["internet"].value_counts().plot(kind="pie")
plt.title('Students want to take higher education & G3')
plt.show()

# %%
# Visualizing relationships using hexbin plots
por_dataset.plot.hexbin(x="Medu",y="G3",gridsize=10)
plt.title('Mother education & G3 (Last grade))')
plt.show()

# %%
por_dataset.plot.hexbin(x="Fedu",y="G3",gridsize=10)
plt.title('Father education & G3 (Last grade)')
plt.show()

# %% [markdown]
# # 6. Visualizing Correlation Matrix

# %%
# Heatmap for correlation visualization
plt.figure(figsize=(12, 8))
sns.heatmap(por_dataset.corr(numeric_only=True))
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # 7. Data Subset

# %%
# Creating a subset of the dataset for modeling
por_dataset_2 = por_dataset[["G1", "G2", "G3", "failures", "studytime", "freetime", "absences", "health", "Dalc", "Walc", "famrel", "schoolsup", "internet",]].copy()
por_dataset_2.head()
# Out:
#    G1  G2  G3  failures  studytime  freetime  absences  health  Dalc  Walc  \
# 0   0  11  11         0          2         3         4       3     1     1
# 1   9  11  11         0          2         3         2       3     1     1
# 2  12  13  12         0          2         3         6       3     2     3
# 3  14  14  14         0          3         2         0       5     1     1
# 4  11  13  13         0          2         3         0       5     1     2
#
#    famrel schoolsup internet
# 0       4       yes       no
# 1       5        no      yes
# 2       4       yes      yes
# 3       3        no      yes
# 4       4        no       no

# %%
# Regression plot based on study time and grades
plt.figure(figsize=(12, 8))
plt.title("Grades based on study time")
sns.regplot(x="studytime", y="G1", data=por_dataset_2, color="orange",label="G1: First Period Grades", scatter= False, ci= None)
sns.regplot(x="studytime", y="G2", data=por_dataset_2, color="red", label="G2: Second Period Grades", scatter= False, ci= None)
sns.regplot(x="studytime", y="G3", data=por_dataset_2, color="blue", label="G3: Final Period Grades", scatter= False, ci= None)
plt.xlabel("Study Time")
plt.ylabel("Grades")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 8. Multiple Linear Regression Modeling

# %%
# Linear regression model creation and evaluation
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# Define X (Features) and y (Labels) variables
X = por_dataset_2["studytime"]
y = por_dataset_2["G3"]

# %%
# Function to create linear regression models
def linear_model(df, feature_variables, target_variable):
  X = np.array(df[feature_variables])
  y = np.array(df[target_variable])

  # Splitting the data into training and testing sets
  X_train, X_test, y_train, y_test = train_test_split(X,
                                                      y,
                                                      test_size=0.2,
                                                      random_state=0)

  # Creating and fitting the linear regression model
  lr = LinearRegression()
  lr.fit(X_train, y_train)

  # Making predictions and creating a dataframe for results
  y_pred = lr.predict(X_test)
  dictionary = {}

  for feature in feature_variables:
    dictionary[feature] = X_test[:, feature_variables.index(feature)]

  lr_results = pd.DataFrame.from_dict(dictionary)
  lr_results["Ground Truth"] = y_test
  lr_results["Prediction"] = y_pred

  # Printing model evaluation metrics
  print("Target:",target_variable)
  print("Features:", feature_variables)
  print("The accuracy of the model is:", lr.score(X_test, y_test))
  print("The MAE of the model is:", mean_absolute_error(y_test, y_pred))
  print("The intercept (alpha) is:", lr.intercept_)
  print("The coeficients (betas) are: ", lr.coef_)

  return lr_results.head()

# %%
# Usage of linear_model with different sets of features
linear_model(por_dataset_2, ["G1", "G2", "studytime"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime']
# The accuracy of the model is: 0.8622120910268749
# The MAE of the model is: 0.7633374334655942
# The intercept (alpha) is: -0.5734796611477204
# The coeficients (betas) are:  [0.1490361  0.91634348 0.08643885]
#    G1  G2  studytime  Ground Truth  Prediction
# 0   9   7          2             8    7.355127
# 1  14  14          3            15   14.601151
# 2  15  16          2            16   16.496435
# 3  10  10          1            10   10.166755
# 4   9   9          1            10    9.101375

# %%
linear_model(por_dataset_2, ["G1", "G2", "studytime", "freetime", "failures", "absences"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime', 'freetime', 'failures', 'absences']
# The accuracy of the model is: 0.8637959119068197
# The MAE of the model is: 0.7535429932702663
# The intercept (alpha) is: -0.2280480720548237
# The coeficients (betas) are:  [ 0.14309273  0.90338475  0.08790417 -0.05277017 -0.23678836  0.02437577]
#    G1  G2  studytime  freetime  failures  absences  Ground Truth  Prediction
# 0   9   7          2         2         0         2             8    7.502499
# 1  14  14          3         3         0         0            15   14.528039
# 2  15  16          2         2         0         6            16   16.589022
# 3  10  10          1         2         0         0            10   10.219091
# 4   9   9          1         4         1         0            10    8.830284

# %%
linear_model(por_dataset_2, ["G1", "G2", "studytime", "freetime", "absences"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime', 'freetime', 'absences']
# The accuracy of the model is: 0.8642576086396676
# The MAE of the model is: 0.75366357796522
# The intercept (alpha) is: -0.49728641498729864
# The coeficients (betas) are:  [ 0.15366661  0.91327016  0.09428168 -0.06077732  0.02214515]
#    G1  G2  studytime  freetime  absences  Ground Truth  Prediction
# 0   9   7          2         2         2             8    7.389903
# 1  14  14          3         3         0            15   14.540341
# 2  15  16          2         2         6            16   16.619915
# 3  10  10          1         2         0            10   10.144808
# 4   9   9          1         4         0            10    8.956317

# %%
linear_model(por_dataset_2, ["G1", "G2", "studytime", "health"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime', 'health']
# The accuracy of the model is: 0.8637825184461433
# The MAE of the model is: 0.7580951712560724
# The intercept (alpha) is: -0.3779786760582695
# The coeficients (betas) are:  [ 0.15022666  0.91385969  0.08419319 -0.0495033 ]
#    G1  G2  studytime  health  Ground Truth  Prediction
# 0   9   7          2       5             8    7.291949
# 1  14  14          3       2            15   14.672803
# 2  15  16          2       1            16   16.616059
# 3  10  10          1       4            10   10.149065
# 4   9   9          1       2            10    9.183985

# %%
linear_model(por_dataset_2, ["G1", "G2", "studytime", "failures", "Dalc", "famrel"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime', 'failures', 'Dalc', 'famrel']
# The accuracy of the model is: 0.8621673911387006
# The MAE of the model is: 0.7644227998611713
# The intercept (alpha) is: 0.21652520423132948
# The coeficients (betas) are:  [ 0.13310998  0.90779171  0.07047158 -0.22670258 -0.09637106 -0.07108344]
#    G1  G2  studytime  failures  Dalc  famrel  Ground Truth  Prediction
# 0   9   7          2         0     1       4             8    7.529295
# 1  14  14          3         0     2       3            15   14.594571
# 2  15  16          2         0     3       4            16   16.305338
# 3  10  10          1         0     1       5            10   10.244225
# 4   9   9          1         1     1       4            10    9.047705

# %%
linear_model(por_dataset_2, ["G1", "G2", "studytime", "failures", "Walc", "famrel"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime', 'failures', 'Walc', 'famrel']
# The accuracy of the model is: 0.8591505021206097
# The MAE of the model is: 0.7724157355855895
# The intercept (alpha) is: 0.28807478124275754
# The coeficients (betas) are:  [ 0.13474719  0.90714382  0.05754362 -0.23765381 -0.07811233 -0.07674957]
#    G1  G2  studytime  failures  Walc  famrel  Ground Truth  Prediction
# 0   9   7          2         0     4       4             8    7.346446
# 1  14  14          3         0     3       3            15   14.582594
# 2  15  16          2         0     4       4            16   16.319223
# 3  10  10          1         0     2       5            10   10.224556
# 4   9   9          1         1     1       4            10    9.099873

# %%
linear_model(por_dataset_2, ["G1", "G2", "failures", "studytime", "freetime", "absences", "health", "Dalc", "Walc", "famrel"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'failures', 'studytime', 'freetime', 'absences', 'health', 'Dalc', 'Walc', 'famrel']
# The accuracy of the model is: 0.8629688482033158
# The MAE of the model is: 0.7542981757419355
# The intercept (alpha) is: 0.348823855032558
# The coeficients (betas) are:  [ 0.13945339  0.90072196 -0.2442839   0.0698367  -0.02918863  0.02660309
#  -0.03122785 -0.06927649 -0.05103877 -0.05573785]
#    G1  G2  failures  studytime  freetime  absences  health  Dalc  Walc  \
# 0   9   7         0          2         2         2       5     1     4
# 1  14  14         0          3         3         0       2     2     3
# 2  15  16         0          2         2         6       1     3     4
# 3  10  10         0          1         2         0       4     1     2
# 4   9   9         1          1         4         0       2     1     1
#
#    famrel  Ground Truth  Prediction
# 0       4             8    7.390938
# 1       3            15   14.511884
# ...
